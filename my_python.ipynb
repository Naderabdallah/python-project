# %% [markdown]
# ## Calculator Project

# %% [markdown]
# ## Summation Function

# %%
# Write your code here
def summ(x, y):
    return x + y

# %% [markdown]
# ## Subtraction Function

# %%
# Write your code here
def sub(a, b):
    return a - b
